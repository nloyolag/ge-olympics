# %%
import gzip
import json
import pandas as pd
import os
import numpy as np
import multiprocessing
import re
from functools import reduce, partial
from vaderSentiment.vaderSentiment import sentiment as vaderSentiment

# %%
tweets = []
with gzip.open("./olympics/2016-08-02-14.gz") as f:
    for line in f.readlines():
        tweets.append(json.loads(line))

dataset = pd.DataFrame(tweets)

# %%
# Create additional columns
dataset['screen_name'] = dataset.user.map(lambda x: x['screen_name'].lower())
dataset['name'] = dataset.user.map(lambda x: x['name'].lower())
dataset['statuses_count'] = dataset.user.map(lambda x: x['statuses_count'])
dataset['followers_count'] = dataset.user.map(lambda x: x['followers_count'])
dataset['text_lower'] = dataset.text.apply(lambda x: x.lower())

# %%
ge_accounts = ['generalelectric', 
               'ge_reports', 
               'gedobrasil', 
               'ge_canada', 
               'gehealthcare', 
               'ge_digital', 
               'gedesign', 
               'ge_water', 
               'gecareeers_latam', 
               'geaviation', 
               'ge_appliances', 
               'gepublicaffairs', 
               'gecapital', 
               'ge_uk', 
               'geinfosec', 
               'ge_power', 
               'geresearch', 
               'ge_oilandgas', 
               'gelighting', 
               'ge_foundation', 
               'ge_gaspower']
dataset['retweeted_status'][2]
# Out:
# nan

# %%
# Volume
volume_dict = {}

# Tweets by GE
ge_tweets = dataset[dataset['screen_name'].isin(ge_accounts)]
volume_dict["tweets-by-ge"] = len(ge_tweets)

# Followers and tweet count per account
volume_dict['accounts'] = {}
ge_tweets_unique = ge_tweets.drop_duplicates(subset='screen_name')
ge_tweets_unique = ge_tweets_unique[['name', 'screen_name', 'statuses_count', 'followers_count']]
for index, row in ge_tweets_unique.iterrows():
    volume_dict['accounts'][row['screen_name']] = {
        'name': row['name'],
        'tweets': row['statuses_count'],
        'followers': row['followers_count'] 
    }
         
# Function to get counts per element
def get_counts(elem_list, volume_dict, dataset, key):
    current_count = 0
    total_count = 0
    for elem in elem_list:
        current_count = len(dataset[dataset['text_lower'].str.contains(elem)])
        volume_dict[key][elem] = current_count
        total_count += current_count
    return total_count

# Function to get counts for a regex
def get_regex_counts(volume_dict, dataset, key, regex, regexstr):
    count = len(dataset[dataset['text_lower'].str.match(regex)])
    volume_dict[key][regexstr] = count
    return count

# Dataset excluding GE's accounts
exclude_ge = dataset[~dataset['screen_name'].isin(ge_accounts)]
    
# Mentions of GE accounts
volume_dict['mentions'] = {}
ge_mentions = list(ge_accounts)
ge_mentions = ['@{0}'.format(account) for account in ge_mentions]
ge_regex = re.compile('@ge | @ge$')
total_mentions = get_counts(ge_mentions, volume_dict, exclude_ge, 'mentions')
total_mentions += get_regex_counts(volume_dict, exclude_ge, 'mentions', ge_regex, "@ge")
volume_dict['total_mentions'] = total_mentions

# Hashtags of GE
volume_dict['hashtags'] = {}
ge_hashtags = list(ge_accounts)
ge_hashtags = ['#{0}'.format(account) for account in ge_mentions]
ge_hashtags.append("#general_electric")
ge_hashtag_regex = re.compile('#ge | #ge$')
ge_dollar_regex = re.compile('\$ge | \$ge$')
total_hashtags = get_counts(ge_hashtags, volume_dict, exclude_ge, 'hashtags')
total_hashtags = get_regex_counts(volume_dict, exclude_ge, 'hashtags', ge_dollar_regex, "$ge")
total_hashtags = get_regex_counts(volume_dict, exclude_ge, 'hashtags', ge_hashtag_regex, "#ge")
volume_dict['total_hashtags'] = total_hashtags

# GE mentioned in text
volume_dict['text_mentions'] = {}
ge_text = ['general electric', 'generalelectric']
ge_website_regex = re.compile('ge.com | ge.com$')
total_hashtags = get_counts(ge_text, volume_dict, exclude_ge, 'text_mentions')
total_hashtags += get_regex_counts(volume_dict, exclude_ge, 'text_mentions', ge_website_regex, "ge.com")
volume_dict['total_text_mentions'] = total_hashtags
# Out:
#           screen_name                                         text_lower
# 0             ebaykix  #ebaykix nike lunarepic low flyknit oc olympic...
# 1              syl20a  official sponsors don't have edge when it come...
# 2       kennethberard  rt @optimy good #commercial from @united to su...
# 3           jibodrift  rt @lee_young_jae: absolute olympic ban on rus...
# 4        rovuxamuvupo  rt @xxsonyxx16: i liked a @youtube video from ...
# 5     l_slierodriguez  watching replays of men's olympic gymnastic tr...
# 6        deannabartik  freak waves lash olympic broadcasting building...
# 7              zhoffs  rt @danijelanusbaum: the best olympic beauty s...
# 8         sh_eventing  rt @horseandhound: fans urged to support eques...
# 9           duncperry  rt @britishdressage: we need you!  our olympic...
# 10     thenewkgbeerme  rt @pardonmytake: olympic update - member of s...
# 11     oklahomacity36  oklahoma city thunder rookie alex abrines offi...
# 12      olympics_data  https://t.co/um4lgkodi5 united states &amp; gr...
# 13      bertramreed25  olympic athletes question lizzie armitstead's ...
# 14           holaday1  rt @olympics: beach volleyball at night! ­ƒÿì­ƒÅÉÝá╝...
# 15      olympique24_7  rio games: andrew bogut rips rooms in olympic ...
# 16      sarahdenholmx  rt @britishdressage: we need you!  our olympic...
# 17    coolmixofficial  https://t.co/aanpwog6jm #champion for a #cause...
# 18        uncleprober  rt @bigshowfactoids: the olympic games used to...
# 19          jrkinnear  rt @banyana_banyana: the magnificent olympic s...
# 20           fullress  8/5Õ▒òÚûï´╝ü\nnike idÒüïÒéëolympicÒü«3ÒüñÒü«ÒâíÒé┐Òâ¬ÒââÒé»Òé½Òâ®Òâ╝ÒÇüÕÉäÕø¢ÒéÆÒéñÒâíÒâ╝Òé©ÒüùÒüƒ...
# 21        ruchapatel5  the thousand miles club! brilliant clip sees t...
# 22      beatrice82766  this oughta get australia&amp;rsquo;s olympic ...
# 23       footballso2s  corona's keys to winning olympic gold\nhttps:/...
# 24         bill_flood  rt @wherewelive: displacement of the poor and ...
# 25         runwithjcu  rt @olympics: only 3 days to go! ­ƒçº­ƒçÀ #roadtor...
# 26      davison_tf_xc  rt @stevenagonzale1: olympic track &amp; field...
# 27       lvandenassum  rt @dutchmfa: the dutch olympic team on its wa...
# 28     campaignliveus  top five official olympic sponsor ads trending...
# 29      simon29237582  rt @kthopkins: facebook has 51 gender options....
# ...               ...                                                ...
# 6231          lyndifc  rt @ambassadorpower: syrian yusra mardini, 18,...
# 6232       willie_30_  rt @ashtonjeaton: olympic village rooms #ashto...
# 6233  _elliemaybarron  rt @waynelineker: my bro is doin the big olymp...
# 6234     chargabriela  rt @dailymail: us menÔÇÖs olympic basketball tea...
# 6235          wdfloyd  rt @washingtonpost: sochi revisited: olympic a...
# 6236       naddy_icee  @sportsbuzztv do people even watch basketball ...
# 6237         ssrs8888  all the best indian contingent for rio olympic...
# 6238      jimi1010ali  twitter announces plans for rio 2016 olympic g...
# 6239    mustafamlk786  rt @olympics: this is what happens when you co...
# 6240       dee_forson  rt @dailymail: us menÔÇÖs olympic basketball tea...
# 6241         blayke24  rt @espnnba: you could say andrew bogut wasn't...
# 6242           srjimm  rt @dsabonis11: finally here at the olympic vi...
# 6243   johnscarlett12  rt @washingtonpost: sochi revisited: olympic a...
# 6244      lysdexicone  i just remembered though, zarya should not get...
# 6245         alexst30  rt @lalocaraballos: .@atodomomento_  urgente: ...
# 6246      iamdeawkung  rt @espnnba: you could say andrew bogut wasn't...
# 6247      stevewalls8  rt @espnnba: you could say andrew bogut wasn't...
# 6248    lostevent_ldn  pre olympic party @ the golden horseshoe #lond...
# 6249    gariochsports  olympic fever has hit the gsc, best wishes to ...
# 6250        usmdindia  david hughes: london, zika, and the rio olympi...
# 6251         amiryogi  rt @olympics: this is what happens when you co...
# 6252    samcardillo12  rt @olympics: a behind the scenes look at the ...
# 6253         pc_fdsja  rt @ctvnews: olympic athletes, visitors warned...
# 6254       beeasy1028  rt @espnnba: you could say andrew bogut wasn't...
# 6255  generiktaughtme  rt @pardonmytake: olympic update - member of s...
# 6256    realdealpicks  rt: https://t.co/taspcxd1ps you could say andr...
# 6257  indiasportscafe  norman pritchard | the mystery man who won ind...
# 6258    realadvicegal  fun games to #getreadyforgold shop at @safeway...
# 6259        gabydavet  rt @olympics: this is what happens when you co...
# 6260         aliplonk  rt @pardonmytake: olympic update - member of s...
#
# [6230 rows x 2 columns]

# %%
top_participants = exclude_ge[['screen_name', 'text_lower']].groupby('screen_name').agg('count').sort('text_lower', ascending=False).rename(columns={'text_lower': 'count'})
top_participants
# Out:
#                  count
# screen_name
# originaloffers      16
# jpasalagua          13
# zaroonrkhan         11
# zicutakeolympic      8
# beautycrib_tv        6
# soldier76bot         6
# ebayticketsales      6
# teresoca2013         5
# news835              5
# andytelasai          5
# battlesreggie        5
# pulseghana           5
# sneakerfitscom       5
# solelynews           5
# sonokhakan           4
# nelsoncarterjr       4
# noopurke             4
# imransohail270       4
# mariecountryman      4
# 7763038147a          4
# nancykathleen        4
# ram40769             4
# chadcougars          4
# bobbyedegbo          4
# easy2earn1           4
# emperordarroux       4
# aigbanegbe           4
# ttgameplan           4
# freshjaykris         3
# alamortiz92          3
# ...                ...
# goodlollipop         1
# gonnelienr           1
# golfingcorner        1
# golfexaminer         1
# golfcourier          1
# golf365dotcom        1
# gnomeoffender        1
# gnngymnastnews       1
# gowillferrell        1
# gpscolour            1
# gringabrazilien      1
# grace_19_ward        1
# grimblazer           1
# griffin_madden       1
# greyinggeekjon       1
# gregdb2011           1
# gregargoscbs3        1
# grechrist            1
# greatmarketnews      1
# greatbossmoves       1
# grayscott_           1
# grantwahl            1
# grantnicol1          1
# grantdenisov         1
# grandpasickz         1
# grandedaley          1
# grahamharriss        1
# graficusdesign       1
# gracynpiresxoxo      1
# zzjdeleon0220        1
#
# [5625 rows x 1 columns]
